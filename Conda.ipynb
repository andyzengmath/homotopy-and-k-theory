# %%
# !pip install -q condacolab

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-cb40cf64-ca78-b495-fe7c-adeb8a277eec)

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:41
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 4.9.2

# %%
# !conda update -n base conda
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     brotlipy-0.7.0             |py37h540881e_1004         342 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     certifi-2022.6.15          |   py37h89c1867_0         155 KB  conda-forge
#     cffi-1.15.1                |   py37h43b0acd_0         227 KB  conda-forge
#     charset-normalizer-2.1.0   |     pyhd8ed1ab_0          35 KB  conda-forge
#     colorama-0.4.5             |     pyhd8ed1ab_0          18 KB  conda-forge
#     conda-4.13.0               |   py37h89c1867_1         989 KB  conda-forge
# ...

# %%
# !conda update anaconda
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /usr/local
#   package name: anaconda

# %%
import sys

# %%
print(sys.path)
# Out:
# ['/usr/local/lib/python3.7/site-packages', '', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/XCS234-A2-main/src
# Out:
# /content/drive/MyDrive/Colab Notebooks/XCS234-A2-main/src

# %%
# !ls

# %%
# !conda env create --file environment.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ...
# libvpx-1.7.0         | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# pysocks-1.7.1        | 31 KB     | : 100% 1.0/1 [00:00<00:00,  5.44it/s]
# pip-22.1.2           | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
# send2trash-1.8.0     | 19 KB     | : 100% 1.0/1 [00:00<00:00,  4.03it/s]
# cachetools-4.2.2     | 13 KB     | : 100% 1.0/1 [00:00<00:00,  5.97it/s]
# google-auth-2.6.0    | 83 KB     | : 100% 1.0/1 [00:00<00:00,  5.63it/s]
# pyrsistent-0.18.0    | 94 KB     | : 100% 1.0/1 [00:00<00:00,  5.58it/s]
# absl-py-0.15.0       | 103 KB    | : 100% 1.0/1 [00:00<00:00,  5.77it/s]
# libidn2-2.3.2        | 81 KB     | : 100% 1.0/1 [00:00<00:00,  5.91it/s]
# blinker-1.4          | 23 KB     | : 100% 1.0/1 [00:00<00:00,  6.02it/s]
# ...

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# XCS234_A2                /usr/local/envs/XCS234_A2

# %%
# !conda activate XCS234_A2
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# %conda init bash
# Out:
# UsageError: Line magic function `%conda` not found.

# %%
# !source activate XCS234_A2 && python run.py --config_filename=q5_linear
# Out:
# ...
# /usr/local/envs/XCS234_A2/lib/python3.8/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, '__version__') or LooseVersion(tensorboard.__version__) < LooseVersion('1.15'):
# Running model on device cpu
# Initializing parameters randomly
# Evaluating...
# Average reward: -0.20 +/- 0.00
#  1001/10000 [==>...........................] - ETA: 5s - Loss: 0.6062 - Avg_R: 1.1600 - Max_R: 5.7000 - eps: 0.8020 - Grads: 1.0193 - Max_Q: 1.0435 - lr: 0.0042
# Evaluating...
# Average reward: 6.20 +/- 0.00
#  2001/10000 [=====>........................] - ETA: 5s - Loss: 0.5774 - Avg_R: 1.9600 - Max_R: 6.2000 - eps: 0.6040 - Grads: 0.7265 - Max_Q: 2.1926 - lr: 0.0034
# Evaluating...
# Average reward: 6.20 +/- 0.00
#  3001/10000 [========>.....................] - ETA: 5s - Loss: 1.5278 - Avg_R: 2.2750 - Max_R: 6.2000 - eps: 0.4060 - Grads: 2.2625 - Max_Q: 3.1419 - lr: 0.0026
# ...

# %%
# !source activate XCS234_A2 && python run.py --config_filename=q6_dqn
# Out:
# ...
# /usr/local/envs/XCS234_A2/lib/python3.8/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, '__version__') or LooseVersion(tensorboard.__version__) < LooseVersion('1.15'):
# Running model on device cpu
# Initializing parameters randomly
# Evaluating...
# Average reward: -1.50 +/- 0.00
#  1001/10000 [==>...........................] - ETA: 325s - Loss: 0.4457 - Avg_R: -0.6150 - Max_R: 3.6000 - eps: 0.8762 - Grads: 1.3365 - Max_Q: 1.8517 - lr: 0.0042
# Evaluating...
# Average reward: 6.00 +/- 0.00
#  2001/10000 [=====>........................] - ETA: 324s - Loss: 0.7150 - Avg_R: 1.5500 - Max_R: 6.2000 - eps: 0.7525 - Grads: 8.6055 - Max_Q: 2.8683 - lr: 0.0034
# Evaluating...
# Average reward: 6.00 +/- 0.00
# ...

# %% [markdown]
# # Setting up GPU

# %%
# !conda env create --file environment_gpu.yml
# Out:
# done
# done
#
# ...
# importlib_resources- | 21 KB     | : 100% 1.0/1 [00:00<00:00,  6.61it/s]
# c-ares-1.18.1        | 114 KB    | : 100% 1.0/1 [00:00<00:00,  7.70it/s]
# mkl_fft-1.3.1        | 180 KB    | : 100% 1.0/1 [00:00<00:00,  7.89it/s]
# attrs-21.4.0         | 51 KB     | : 100% 1.0/1 [00:00<00:00,  7.94it/s]
# pip-22.1.2           | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.82it/s]
# libopus-1.3.1        | 491 KB    | : 100% 1.0/1 [00:00<00:00,  7.44it/s]
# numpy-base-1.23.1    | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.79it/s]
# libuv-1.40.0         | 736 KB    | : 100% 1.0/1 [00:00<00:00,  7.23it/s]
# stack_data-0.2.0     | 22 KB     | : 100% 1.0/1 [00:00<00:00,  6.03it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00,  7.94it/s]
# mkl_random-1.2.2     | 308 KB    | : 100% 1.0/1 [00:00<00:00,  7.42it/s]
# markdown-3.3.4       | 129 KB    | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# ptyprocess-0.7.0     | 17 KB     | : 100% 1.0/1 [00:00<00:00,  7.31it/s]
# ...

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# XCS234_A2_GPU            /usr/local/envs/XCS234_A2_GPU

# %%
# !source activate XCS234_A2_GPU && python run.py --config_filename=q7_dqn
# Out:
# ...
# /usr/local/envs/XCS234_A2_GPU/lib/python3.8/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, '__version__') or LooseVersion(tensorboard.__version__) < LooseVersion('1.15'):
# A.L.E: Arcade Learning Environment (version 0.7.5+db37282)
# [Powered by Stella]
# File pretrained_weights/model.weights exists, skipping download
# Running model on device cuda:0
# Loading parameters from file: pretrained_weights/model.weights
# Load successful!
# ...
